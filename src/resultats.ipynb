# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
fichiers = os.listdir('../bin/data/')
fichiers
# Out:
# ['donnees_simulation_replication_50.csv',
#  'donnees_simulation_replication_6.csv',
#  'donnees_simulation_replication_26.csv',
#  'donnees_simulation_replication_7.csv',
#  'donnees_simulation_replication_42.csv',
#  'donnees_simulation_replication_11.csv',
#  'donnees_simulation_replication_86.csv',
#  'donnees_simulation_replication_83.csv',
#  'donnees_simulation_replication_58.csv',
#  'donnees_simulation_replication_23.csv',
#  'donnees_simulation_replication_82.csv',
#  'donnees_simulation_replication_22.csv',
#  'donnees_simulation_replication_74.csv',
#  'donnees_simulation_replication_20.csv',
#  'donnees_simulation_replication_92.csv',
#  'donnees_simulation_replication_65.csv',
#  'donnees_simulation_replication_44.csv',
#  'donnees_simulation_replication_38.csv',
#  'donnees_simulation_replication_29.csv',
#  'donnees_simulation_replication_97.csv',
#  'donnees_simulation_replication_64.csv',
#  'donnees_simulation_replication_93.csv',
#  'donnees_simulation_replication_75.csv',
#  'donnees_simulation_replication_95.csv',
#  'donnees_simulation_replication_8.csv',
#  'donnees_simulation_replication_59.csv',
#  'donnees_simulation_replication_14.csv',
#  'donnees_simulation_replication_61.csv',
#  'donnees_simulation_replication_0.csv',
#  'donnees_simulation_replication_46.csv',
#  'donnees_simulation_replication_62.csv',
#  'donnees_simulation_replication_48.csv',
#  'donnees_simulation_replication_99.csv',
#  'donnees_simulation_replication_24.csv',
#  'donnees_simulation_replication_94.csv',
#  'donnees_simulation_replication_52.csv',
#  'donnees_simulation_replication_49.csv',
#  'donnees_simulation_replication_36.csv',
#  'donnees_simulation_replication_9.csv',
#  'donnees_simulation_replication_41.csv',
#  'donnees_simulation_replication_1.csv',
#  'donnees_simulation_replication_67.csv',
#  'donnees_simulation_replication_40.csv',
#  'donnees_simulation_replication_90.csv',
#  'donnees_simulation_replication_5.csv',
#  'donnees_simulation_replication_4.csv',
#  'donnees_simulation_replication_27.csv',
#  'donnees_simulation_replication_77.csv',
#  'donnees_simulation_replication_12.csv',
#  'donnees_simulation_replication_68.csv',
#  'donnees_simulation_replication_56.csv',
#  'donnees_simulation_replication_19.csv',
#  'donnees_simulation_replication_81.csv',
#  'donnees_simulation_replication_17.csv',
#  'donnees_simulation_replication_63.csv',
#  'donnees_simulation_replication_32.csv',
#  'donnees_simulation_replication_16.csv',
#  'donnees_simulation_replication_31.csv',
#  'donnees_simulation_replication_84.csv',
#  'donnees_simulation_replication_98.csv',
#  'donnees_simulation_replication_57.csv',
#  'donnees_simulation_replication_13.csv',
#  'donnees_simulation_replication_76.csv',
#  'donnees_simulation_replication_2.csv',
#  'donnees_simulation_replication_91.csv',
#  'donnees_simulation_replication_34.csv',
#  'donnees_simulation_replication_80.csv',
#  'donnees_simulation_replication_69.csv',
#  'donnees_simulation_replication_72.csv',
#  'donnees_simulation_replication_88.csv',
#  'donnees_simulation_replication_96.csv',
#  'donnees_simulation_replication_60.csv',
#  'donnees_simulation_replication_33.csv',
#  'donnees_simulation_replication_37.csv',
#  'donnees_simulation_replication_30.csv',
#  'donnees_simulation_replication_54.csv',
#  'donnees_simulation_replication_55.csv',
#  'donnees_simulation_replication_53.csv',
#  'donnees_simulation_replication_43.csv',
#  'donnees_simulation_replication_18.csv',
#  'donnees_simulation_replication_51.csv',
#  'donnees_simulation_replication_35.csv',
#  'donnees_simulation_replication_89.csv',
#  'donnees_simulation_replication_28.csv',
#  'donnees_simulation_replication_47.csv',
#  'donnees_simulation_replication_87.csv',
#  'donnees_simulation_replication_71.csv',
#  'donnees_simulation_replication_3.csv',
#  'donnees_simulation_replication_79.csv',
#  'donnees_simulation_replication_45.csv',
#  'donnees_simulation_replication_10.csv',
#  'donnees_simulation_replication_85.csv',
#  'donnees_simulation_replication_39.csv',
#  'donnees_simulation_replication_78.csv',
#  'donnees_simulation_replication_21.csv',
#  'donnees_simulation_replication_73.csv',
#  'donnees_simulation_replication_15.csv',
#  'donnees_simulation_replication_70.csv',
#  'donnees_simulation_replication_25.csv',
#  'donnees_simulation_replication_66.csv']

# %%
# Lecture de chaque fichiers et les stocker dans une liste
data = []
for fic in fichiers :
    df = pd.read_csv('../bin/data/' + fic)
    data.append(df)

# %%
"""
- Enlever la colonne jour car c'est une repetition de la colonne d'indice
- Vérifer que la somme des individus est égale à 20000
"""
for replication in data :
    replication.drop(['Jour'], axis=1, inplace=True)
    replication['Somme'] = replication.sum(axis=1)
    boolean = True
    if (replication['Somme'].eq(20000).all() == False) : #Pour verifier si pour toutes les replications, la somme des individus égale à 20000
        boolean = False

"""
- Faire la moyenne des touts les fichiers et la stocker dans `moyenne`
- Calculer le pourcetage des populations et le stocker dans `pourcentage`
"""
if boolean :
    moyenne = 0
    for replication in data :
        moyenne += replication
    moyenne /= len(data)
    pourcentage = moyenne[['Susceptible', 'Exposed', 'Infected', 'recovered']].div(moyenne['Somme'], axis=0)

# %%
pourcentage['Susceptible'].plot()
pourcentage['Exposed'].plot()
pourcentage['Infected'].plot()
pourcentage['recovered'].plot()
plt.title("S, E, I and R agents population over time")
plt.xlabel("Time in days")
plt.ylabel("Ratio of agents in each state")
plt.legend()
plt.show()
